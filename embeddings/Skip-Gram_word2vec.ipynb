# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

# %%
dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:48, 640KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import math
import random

# %%
## Your code here
threshold = 1e-5
counter_words = Counter(int_words)
total_count = len(int_words)


frequencies = {word:count/total_count for word,count in counter_words.items()}    
drop_prob_per_word= {word:(1-np.sqrt(threshold/frequencies[word])) for word in counter_words}
train_words = [word for word in int_words if drop_prob_per_word[word]< random.random()]# The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1,window_size+1)
    start = idx-R if (idx-R) > 0 else 0
    end = idx + R

    targets = set(words[start:idx]+ words[idx+1:end+1]) #we use becasuse it gets rid of duplicates
    return targets

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding), -1,1))  # create embedding weight matrix here
    embed =tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))    
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6683 0.0682 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5748 0.0657 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4873 0.0661 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6218 0.0660 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5003 0.0657 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5209 0.0656 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5693 0.0668 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5590 0.0667 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4862 0.0671 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4531 0.0672 sec/batch
# Nearest to three: nexgen, espousing, pasadena, reorganizing, bacterium, slough, excelling, mariette,
# Nearest to in: hippias, steric, kommune, cumbria, l, merrill, misunderstanding, cappella,
# Nearest to have: catechism, necronomicon, dava, schafer, centrifugal, schengen, honorary, rampton,
# Nearest to five: habitual, an, joliot, montgomery, notes, smalley, aida, copyright,
# Nearest to first: epping, cooks, substituting, confirmed, finian, incorporation, supporters, undermining,
# Nearest to time: regencies, heterotic, most, scooter, kaddish, chungcheong, plovdiv, gallus,
# Nearest to over: redeemer, both, enumerated, necessitating, sticks, dromedary, alameda, arjuna,
# Nearest to not: partitioning, tutelage, fullmetal, therefore, elephants, bir, inference, teased,
# Nearest to grand: macrophages, aruch, embodying, semiarid, dignified, combined, orgel, around,
# Nearest to award: oblique, tanzanian, yo, salt, bristles, nova, ambitious, brand,
# Nearest to assembly: ft, owes, anic, lemming, internationally, saucer, wargaming, ritual,
# Nearest to cost: narn, recommends, flexible, mits, kodokan, additives, allegedly, sauropods,
# Nearest to creation: copenhagen, involvements, efik, sizeof, convene, railhead, mill, doomsday,
# Nearest to engineering: diez, connectionless, unconvincing, kampuchea, cubs, hyrcanus, jouvenel, tptp,
# Nearest to test: diminishes, islander, tort, bidatsu, charlie, explains, fsb, plebeians,
# Nearest to ice: galician, unpaved, hizbullah, discotheque, agrarianism, fulfills, vagrant, umpires,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4901 0.0716 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3905 0.0694 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2954 0.0687 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2211 0.0698 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1672 0.0690 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1461 0.0695 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1005 0.0693 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0656 0.0694 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9833 0.0704 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9674 0.0806 sec/batch
# Nearest to three: si, nexgen, pasadena, yet, espousing, reorganizing, banknotes, leq,
# Nearest to in: hippias, l, steric, firms, local, misunderstanding, merrill, destroyed,
# Nearest to have: catechism, necronomicon, them, centrifugal, honorary, mental, schafer, dava,
# Nearest to five: an, with, notes, habitual, uncertain, romanticism, creates, approximately,
# Nearest to first: confirmed, substituting, red, supporters, incorporation, epping, historic, characterised,
# Nearest to time: most, regencies, finland, deep, chungcheong, wasn, phases, scooter,
# Nearest to over: both, redeemer, sometimes, sticks, home, enumerated, necessitating, is,
# Nearest to not: therefore, partitioning, requires, newer, elephants, tutelage, semi, think,
# Nearest to grand: aruch, combined, around, macrophages, embodying, dignified, cyborgs, orgel,
# Nearest to award: oblique, salt, nova, ambitious, photographs, brand, tanzanian, saving,
# Nearest to assembly: ft, internationally, owes, wargaming, lemming, anic, ritual, trained,
# Nearest to cost: recommends, flexible, narn, allegedly, error, lifetime, some, additives,
# Nearest to creation: copenhagen, involvements, humans, mill, doomsday, violet, approximate, example,
# Nearest to engineering: cubs, connectionless, diez, hurt, expensive, kampuchea, expectancies, unconvincing,
# Nearest to test: diminishes, islander, explains, charlie, modern, plebeians, geoff, loose,
# Nearest to ice: unpaved, galician, hizbullah, agrarianism, subjects, exotic, altogether, pen,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9388 0.0707 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9099 0.0851 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8767 0.0725 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8276 0.0718 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8286 0.0698 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8106 0.0698 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8035 0.0696 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8022 0.0698 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7865 0.0697 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7922 0.0699 sec/batch
# Nearest to three: pasadena, si, fetches, leq, banknotes, byzantine, slough, irish,
# Nearest to in: hippias, steric, engineers, posted, l, merrill, firms, local,
# Nearest to have: catechism, necronomicon, centrifugal, kyle, donors, patients, them, schafer,
# Nearest to five: romanticism, aryans, patriot, yorkshire, uncertain, january, habitual, leonardo,
# Nearest to first: confirmed, substituting, incorporation, supporters, intellect, epping, charge, wonderful,
# Nearest to time: regencies, most, deep, chungcheong, wasn, relies, sixteen, finland,
# Nearest to over: both, enumerated, necessitating, sticks, redeemer, home, money, sometimes,
# Nearest to not: partitioning, semi, therefore, requires, elephants, inference, kind, doesn,
# Nearest to grand: aruch, dignified, combined, around, embodying, macrophages, cyborgs, abstract,
# Nearest to award: oblique, brand, ambitious, photographs, salt, inhaled, ton, ratification,
# Nearest to assembly: internationally, owes, ft, wargaming, lemming, anic, museum, trained,
# Nearest to cost: recommends, error, flexible, narn, allegedly, additives, explaining, permian,
# Nearest to creation: copenhagen, involvements, humans, mill, convene, doomsday, participatory, redistribute,
# Nearest to engineering: cubs, hurt, expensive, connectionless, diez, monarchies, letter, grown,
# Nearest to test: diminishes, islander, explains, charlie, roars, illusion, loose, geoff,
# Nearest to ice: unpaved, galician, thickness, fulfills, exotic, hizbullah, agrarianism, altogether,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7869 0.0717 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7742 0.0698 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7374 0.0711 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7406 0.0868 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7341 0.0901 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6979 0.0896 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7165 0.0900 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7060 0.0923 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6955 0.0925 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6594 0.0911 sec/batch
# Nearest to three: nine, pasadena, eight, fetches, clemens, inventor, leq, irish,
# Nearest to in: hippias, engineers, posted, cappella, merrill, steric, local, amongst,
# Nearest to have: necronomicon, catechism, centrifugal, donors, them, kyle, mental, schengen,
# Nearest to five: january, patriot, seven, one, aryans, horatio, gina, yorkshire,
# Nearest to first: confirmed, substituting, epping, incorporation, undermining, intellect, danville, supporters,
# Nearest to time: regencies, most, konoe, chungcheong, scooter, sixteen, relies, deep,
# Nearest to over: both, enumerated, necessitating, home, redeemer, money, sticks, salvation,
# Nearest to not: therefore, partitioning, requires, semi, elephants, doesn, teased, think,
# Nearest to grand: aruch, dignified, embodying, macrophages, around, combined, hejaz, zilog,
# Nearest to award: brand, oblique, inhaled, carib, ton, ratification, ambitious, photographs,
# Nearest to assembly: internationally, owes, anic, lemming, wargaming, battalions, saucer, museum,
# Nearest to cost: error, flexible, recommends, narn, triad, permian, telstra, explaining,
# Nearest to creation: copenhagen, involvements, convene, humans, mill, kosovo, bullion, redistribute,
# Nearest to engineering: cubs, connectionless, diez, hurt, expectancies, gambling, expensive, kampuchea,
# Nearest to test: diminishes, islander, charlie, explains, roars, plebeians, retainers, illusion,
# Nearest to ice: unpaved, galician, discotheque, thickness, tecumseh, digging, meats, fulfills,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6705 0.0891 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6689 0.0871 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6417 0.0861 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6231 0.0873 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6605 0.0860 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6284 0.0902 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5733 0.0672 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5498 0.0928 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5070 0.0846 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5048 0.0919 sec/batch
# Nearest to three: nine, inventor, eight, pasadena, fetches, lyricist, paul, clemens,
# Nearest to in: hippias, steric, engineers, posted, merrill, cappella, local, amongst,
# Nearest to have: necronomicon, catechism, schengen, centrifugal, them, schafer, mental, patients,
# Nearest to five: seven, one, two, zero, eight, de, aryans, six,
# Nearest to first: epping, confirmed, incorporation, substituting, impart, finian, undermining, supporters,
# Nearest to time: regencies, most, chungcheong, scooter, konoe, deep, sixteen, anachronistic,
# Nearest to over: both, enumerated, necessitating, home, redeemer, alameda, danmark, money,
# Nearest to not: therefore, requires, doesn, think, partitioning, elephants, hostilities, teased,
# Nearest to grand: aruch, macrophages, dignified, embodying, around, hejaz, fulani, arda,
# Nearest to award: brand, kramer, conductor, carib, cataclysm, ton, inhaled, vincent,
# Nearest to assembly: anic, internationally, owes, saucer, wargaming, lemming, party, kilmer,
# Nearest to cost: error, recommends, flexible, narn, openoffice, explaining, deceptive, additives,
# Nearest to creation: copenhagen, involvements, convene, humans, doomsday, bullion, mill, kosovo,
# Nearest to engineering: connectionless, diez, getter, cubs, expensive, gambling, hurt, expectancies,
# Nearest to test: diminishes, islander, charlie, explains, roars, loose, plebeians, vanish,
# Nearest to ice: unpaved, tecumseh, galician, discotheque, meats, digging, thickness, schneier,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4788 0.0910 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4874 0.0892 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4504 0.0892 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5490 0.0897 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4870 0.0825 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.5061 0.0745 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4383 0.0838 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4108 0.0743 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4258 0.0804 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4180 0.0786 sec/batch
# Nearest to three: nine, fetches, leq, clemens, banknotes, pasadena, inventor, eight,
# Nearest to in: hippias, steric, engineers, encroachment, cappella, few, merrill, kommune,
# Nearest to have: necronomicon, schengen, them, centrifugal, catechism, patients, fertilize, mental,
# Nearest to five: zero, seven, two, de, eight, aryans, joliot, one,
# Nearest to first: epping, impart, incorporation, undermining, awesome, confirmed, qe, tales,
# Nearest to time: regencies, most, chungcheong, sixteen, scooter, deep, konoe, punter,
# Nearest to over: both, enumerated, necessitating, home, alameda, sticks, arjuna, redeemer,
# Nearest to not: therefore, requires, doesn, think, partitioning, kind, fulfilled, elephants,
# Nearest to grand: aruch, dignified, embodying, macrophages, around, ford, hejaz, fulani,
# Nearest to award: kramer, brand, conductor, photographs, carib, myers, cataclysm, actresses,
# Nearest to assembly: internationally, owes, saucer, anic, wargaming, party, system, lemming,
# Nearest to cost: error, flexible, narn, openoffice, recommends, deceptive, data, withstanding,
# Nearest to creation: copenhagen, involvements, doomsday, kosovo, convene, efik, humans, bullion,
# Nearest to engineering: diez, getter, connectionless, tptp, gambling, expensive, mailing, cubs,
# Nearest to test: diminishes, islander, vanish, loose, roars, tort, explains, charlie,
# Nearest to ice: unpaved, tecumseh, galician, thickness, meats, schneier, digging, vagrant,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4424 0.0741 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4061 0.0822 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4394 0.0802 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3936 0.0878 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4243 0.0806 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4425 0.0788 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3997 0.0805 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3974 0.0838 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4305 0.0782 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3535 0.0804 sec/batch
# Nearest to three: nine, clemens, leq, fetches, eight, banknotes, two, pasadena,
# Nearest to in: hippias, cappella, engineers, steric, few, gawain, julio, merrill,
# Nearest to have: necronomicon, schengen, them, fertilize, catechism, centrifugal, mental, patients,
# Nearest to five: zero, two, seven, eight, one, six, de, four,
# Nearest to first: epping, finian, qe, incorporation, impart, awesome, tales, ehud,
# Nearest to time: regencies, chungcheong, deep, sixteen, most, punter, constructor, scooter,
# Nearest to over: both, enumerated, necessitating, alameda, home, sticks, arjuna, ormond,
# Nearest to not: therefore, requires, partitioning, doesn, kind, inference, think, fulfilled,
# Nearest to grand: aruch, dignified, macrophages, embodying, hejaz, maris, ford, around,
# Nearest to award: kramer, brand, myers, won, actresses, photographs, cataclysm, carib,
# Nearest to assembly: internationally, party, electoral, branch, saucer, anic, wargaming, system,
# Nearest to cost: flexible, error, recommends, data, openoffice, propulsion, narn, withstanding,
# Nearest to creation: copenhagen, involvements, efik, humans, kosovo, doomsday, convene, mill,
# Nearest to engineering: diez, getter, connectionless, gambling, expensive, tptp, mailing, applications,
# Nearest to test: diminishes, islander, loose, vanish, topologically, korzybski, fsb, retainers,
# Nearest to ice: tecumseh, thickness, unpaved, meats, digging, galician, vagrant, schneier,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3671 0.0780 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3841 0.0791 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3640 0.0881 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3859 0.0807 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4118 0.0778 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3834 0.0773 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3863 0.0784 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3947 0.0818 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3265 0.0780 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3386 0.0780 sec/batch
# Nearest to three: nine, leq, two, eight, six, clemens, banknotes, fetches,
# Nearest to in: hippias, cappella, few, qualifications, inefficiencies, engineers, of, encroachment,
# Nearest to have: necronomicon, schengen, fertilize, centrifugal, them, patients, splendour, catechism,
# Nearest to five: zero, two, seven, six, one, eight, four, january,
# Nearest to first: incorporation, epping, substituting, finian, danville, ehud, qe, impart,
# Nearest to time: regencies, chungcheong, deep, sixteen, most, anachronistic, punter, constructor,
# Nearest to over: both, enumerated, necessitating, home, alameda, subdivision, advisable, at,
# Nearest to not: therefore, requires, doesn, partitioning, kind, elephants, itself, fulfilled,
# Nearest to grand: aruch, dignified, embodying, around, boudica, hindrance, macrophages, hejaz,
# Nearest to award: myers, actresses, won, brand, kramer, best, photographs, received,
# Nearest to assembly: internationally, branch, electoral, system, party, pluriform, saucer, anic,
# Nearest to cost: flexible, error, funds, price, propulsion, recommends, data, narn,
# Nearest to creation: involvements, copenhagen, efik, doomsday, kosovo, convene, decaying, ifab,
# Nearest to engineering: diez, getter, connectionless, mailing, tptp, applications, expensive, gambling,
# Nearest to test: diminishes, islander, retainers, vanish, fsb, topologically, korzybski, roars,
# Nearest to ice: thickness, tecumseh, vagrant, layer, digging, unpaved, schneier, meats,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3439 0.0808 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2927 0.0851 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3815 0.0802 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3784 0.0775 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3855 0.0777 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2897 0.0773 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2918 0.0795 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3410 0.0781 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2302 0.0778 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3085 0.0777 sec/batch
# Nearest to three: nine, two, eight, leq, six, clemens, zero, fetches,
# Nearest to in: hippias, cappella, few, inefficiencies, engineers, basaltic, of, qualifications,
# Nearest to have: necronomicon, schengen, splendour, centrifugal, mental, fertilize, impoverished, them,
# Nearest to five: zero, two, one, seven, six, eight, four, horatio,
# Nearest to first: incorporation, finian, substituting, danville, epping, awesome, ehud, photojournalist,
# Nearest to time: regencies, chungcheong, deep, sixteen, anachronistic, most, augmented, scooter,
# Nearest to over: both, subdivision, home, necessitating, enumerated, alameda, advisable, forecasts,
# Nearest to not: therefore, doesn, elephants, partitioning, requires, secrecy, itself, inference,
# Nearest to grand: dignified, aruch, around, maris, embodying, hazor, fulani, arda,
# Nearest to award: myers, best, won, actresses, photographs, brand, academy, awards,
# Nearest to assembly: branch, electoral, internationally, pluriform, system, transferable, council, saucer,
# Nearest to cost: flexible, error, funds, price, data, money, amounting, tbs,
# Nearest to creation: involvements, efik, copenhagen, pang, doomsday, kosovo, mill, ifab,
# Nearest to engineering: diez, getter, connectionless, mailing, applications, tptp, gambling, mulliken,
# Nearest to test: diminishes, islander, demonstrator, retainers, topologically, roars, fsb, korzybski,
# Nearest to ice: thickness, tecumseh, digging, vagrant, unpaved, schneier, meats, layer,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3227 0.0776 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3082 0.0738 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3320 0.0348 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2489 0.0721 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2184 0.0715 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2177 0.0729 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2113 0.0714 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2171 0.0758 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2185 0.0780 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2020 0.0766 sec/batch
# Nearest to three: two, nine, eight, leq, six, zero, si, clemens,
# Nearest to in: hippias, few, cappella, engineers, posted, everyman, of, inefficiencies,
# Nearest to have: necronomicon, schengen, splendour, impoverished, fertilize, centrifugal, aggressors, patients,
# Nearest to five: zero, two, one, six, seven, eight, four, migrant,
# Nearest to first: epping, finian, awesome, photojournalist, incorporation, ehud, substituting, qe,
# Nearest to time: regencies, chungcheong, deep, victory, sixteen, scooter, veishea, anachronistic,
# Nearest to over: both, necessitating, enumerated, subdivision, alameda, home, advisable, at,
# Nearest to not: therefore, doesn, requires, elephants, inference, partitioning, multiplications, itself,
# Nearest to grand: dignified, aruch, around, maris, chops, hindrance, boudica, arda,
# Nearest to award: won, best, actresses, awards, myers, academy, received, stuntman,
# Nearest to assembly: branch, system, electoral, internationally, pluriform, transferable, council, owes,
# Nearest to cost: flexible, price, funds, error, propulsion, maintenance, telstra, amounting,
# Nearest to creation: involvements, efik, copenhagen, doomsday, pang, kosovo, ifab, mill,
# Nearest to engineering: diez, getter, tptp, connectionless, mailing, industrialization, kzinti, macdonough,
# Nearest to test: diminishes, islander, retainers, demonstrator, topologically, wind, roars, fsb,
# Nearest to ice: thickness, vagrant, tecumseh, meats, digging, layer, schneier, summer,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2434 0.0794 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2147 0.0782 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2166 0.0775 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1484 0.0791 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1631 0.0794 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1781 0.0780 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1582 0.0764 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1738 0.0791 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1853 0.0713 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1697 0.0720 sec/batch
# Nearest to three: two, nine, eight, six, leq, zero, four, si,
# Nearest to in: hippias, few, steric, cappella, attracts, inefficiencies, qualifications, everyman,
# Nearest to have: necronomicon, splendour, fertilize, impoverished, chah, schengen, mental, size,
# Nearest to five: zero, two, one, six, eight, seven, four, rate,
# Nearest to first: substituting, awesome, qe, incorporation, tales, wonderful, ehud, danville,
# Nearest to time: chungcheong, regencies, deep, victory, augmented, punter, sixteen, constructor,
# Nearest to over: both, necessitating, enumerated, home, subdivision, at, alameda, advisable,
# Nearest to not: therefore, requires, doesn, elephants, multiplications, partitioning, anyone, inference,
# Nearest to grand: aruch, dignified, around, maris, hindrance, boudica, chops, fulani,
# Nearest to award: awards, won, best, academy, actresses, stuntman, myers, received,
# Nearest to assembly: system, branch, pluriform, electoral, internationally, transferable, bicameral, owes,
# Nearest to cost: flexible, price, funds, error, propulsion, telstra, amounting, recommends,
# Nearest to creation: efik, involvements, doomsday, pang, ifab, kosovo, decaying, participatory,
# Nearest to engineering: diez, getter, tptp, connectionless, industrialization, mailing, development, kzinti,
# Nearest to test: diminishes, islander, retainers, roars, demonstrator, korzybski, topologically, geoff,
# Nearest to ice: thickness, meats, vagrant, layer, digging, spray, tecumseh, schneier,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1668 0.0766 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2062 0.0724 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1641 0.0730 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1577 0.0712 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1981 0.0708 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1806 0.0706 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2106 0.0706 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1514 0.0713 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1410 0.0790 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1606 0.0892 sec/batch
# Nearest to three: two, six, nine, eight, leq, zero, four, si,
# Nearest to in: hippias, few, of, bestsellers, cappella, basaltic, gawain, steric,
# Nearest to have: necronomicon, splendour, chah, schengen, impoverished, centrifugal, fertilize, unsatisfied,
# Nearest to five: zero, two, one, six, eight, seven, four, rate,
# Nearest to first: substituting, incorporation, danville, ehud, qe, wonderful, awesome, unconvincing,
# Nearest to time: chungcheong, regencies, deep, victory, punter, sixteen, veishea, anachronistic,
# Nearest to over: subdivision, enumerated, both, alameda, home, necessitating, ormond, advisable,
# Nearest to not: requires, partitioning, doesn, multiplications, elephants, therefore, inference, itself,
# Nearest to grand: aruch, dignified, hindrance, around, chops, boudica, salmon, arda,
# Nearest to award: awards, academy, won, received, best, actresses, stuntman, ambitious,
# Nearest to assembly: pluriform, branch, electoral, system, bicameral, internationally, transferable, seats,
# Nearest to cost: flexible, price, error, funds, manages, controlling, recommends, propulsion,
# Nearest to creation: doomsday, involvements, pang, efik, decaying, ifab, humans, mill,
# Nearest to engineering: getter, diez, connectionless, applications, development, tptp, mulliken, mailing,
# Nearest to test: diminishes, islander, korzybski, retainers, demonstrator, fsb, topologically, roars,
# Nearest to ice: thickness, vagrant, meats, digging, tecumseh, schneier, creams, spray,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2000 0.0729 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1708 0.0720 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1805 0.0709 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.2068 0.0740 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1417 0.0804 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1558 0.0772 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.2020 0.0794 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1256 0.0743 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1809 0.0743 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2243 0.0743 sec/batch
# Nearest to three: two, nine, six, eight, zero, four, clemens, five,
# Nearest to in: of, hippias, few, cappella, qualifications, year, bestsellers, constitutionality,
# Nearest to have: necronomicon, schengen, impoverished, splendour, chah, ecclesia, catechism, confident,
# Nearest to five: zero, two, one, six, eight, seven, four, three,
# Nearest to first: danville, substituting, incorporation, ehud, wonderful, awesome, arden, finian,
# Nearest to time: chungcheong, regencies, deep, anachronistic, victory, sixteen, most, veishea,
# Nearest to over: subdivision, both, enumerated, necessitating, ormond, alameda, anime, advisable,
# Nearest to not: elephants, partitioning, therefore, ambiguities, requires, secrecy, doesn, teased,
# Nearest to grand: dignified, aruch, hindrance, chops, boudica, around, arda, embodying,
# Nearest to award: awards, academy, received, best, won, actresses, awarded, stuntman,
# Nearest to assembly: pluriform, branch, system, bicameral, electoral, transferable, internationally, amended,
# Nearest to cost: price, funds, flexible, error, amounting, telstra, manages, tax,
# Nearest to creation: doomsday, pang, involvements, efik, ifab, kosovo, mill, copenhagen,
# Nearest to engineering: getter, diez, connectionless, tptp, development, applications, mulliken, industrialization,
# Nearest to test: diminishes, islander, korzybski, demonstrator, retainers, topologically, limitation, disabled,
# Nearest to ice: thickness, vagrant, tecumseh, digging, schneier, meats, spray, creams,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2036 0.0730 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1188 0.0717 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1461 0.0715 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1538 0.0799 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0378 0.0780 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1425 0.0814 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1411 0.0757 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1515 0.0773 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1969 0.0177 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0989 0.0777 sec/batch
# Nearest to three: two, six, nine, eight, zero, four, leq, five,
# Nearest to in: few, hippias, of, attracts, steric, cappella, year, qualifications,
# Nearest to have: necronomicon, schengen, splendour, impoverished, chah, them, brisance, ecclesia,
# Nearest to five: zero, two, one, six, eight, seven, four, migrant,
# Nearest to first: substituting, danville, awesome, epping, wonderful, incorporation, qe, finian,
# Nearest to time: chungcheong, regencies, deep, victory, punter, sixteen, most, anachronistic,
# Nearest to over: subdivision, both, anime, enumerated, necessitating, forecasts, alameda, ormond,
# Nearest to not: partitioning, requires, elephants, ambiguities, therefore, itself, doesn, multiplications,
# Nearest to grand: dignified, chops, aruch, around, hindrance, maris, boudica, chargers,
# Nearest to award: awards, academy, received, best, won, actresses, awarded, recipients,
# Nearest to assembly: pluriform, branch, system, transferable, bicameral, electoral, internationally, council,
# Nearest to cost: price, funds, flexible, amounting, error, manages, telstra, tax,
# Nearest to creation: doomsday, pang, involvements, ifab, mill, efik, decaying, kosovo,
# Nearest to engineering: getter, diez, connectionless, development, tptp, applications, mulliken, industrialization,
# Nearest to test: diminishes, islander, demonstrator, korzybski, topologically, chs, disabled, luf,
# Nearest to ice: thickness, vagrant, tecumseh, meats, digging, spray, schneier, summer,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0849 0.0785 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0654 0.0779 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0794 0.0771 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0456 0.0788 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0676 0.0822 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0353 0.0785 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0984 0.0779 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0738 0.0772 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1137 0.0787 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0219 0.0773 sec/batch
# Nearest to three: two, six, nine, eight, zero, four, five, leq,
# Nearest to in: few, hippias, of, cappella, basaltic, steric, the, year,
# Nearest to have: necronomicon, impoverished, splendour, fertilize, unsatisfied, schengen, size, chah,
# Nearest to five: zero, two, one, eight, six, seven, four, three,
# Nearest to first: substituting, awesome, danville, incorporation, qe, circumcising, epping, photojournalist,
# Nearest to time: chungcheong, regencies, deep, constructor, punter, most, veishea, anachronistic,
# Nearest to over: subdivision, both, ormond, enumerated, necessitating, anime, alameda, female,
# Nearest to not: requires, partitioning, elephants, ambiguities, multiplications, assembler, therefore, itself,
# Nearest to grand: dignified, hindrance, chops, around, aruch, maris, pedersen, boudica,
# Nearest to award: awards, academy, best, received, awarded, won, recipients, honorary,
# Nearest to assembly: pluriform, system, branch, bicameral, transferable, electoral, internationally, amended,
# Nearest to cost: price, funds, flexible, error, amounting, manages, telstra, tax,
# Nearest to creation: doomsday, pang, involvements, ifab, efik, decaying, mill, kosovo,
# Nearest to engineering: getter, diez, development, connectionless, industrialization, applications, tptp, mulliken,
# Nearest to test: diminishes, islander, demonstrator, disabled, wind, korzybski, fsb, topologically,
# Nearest to ice: thickness, vagrant, creams, tecumseh, meats, spray, digging, skier,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0264 0.0793 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0420 0.0772 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0237 0.0781 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0570 0.0777 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0757 0.0775 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0532 0.0785 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0446 0.0744 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0891 0.0718 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0582 0.0722 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0534 0.0724 sec/batch
# Nearest to three: two, six, eight, four, nine, zero, five, leq,
# Nearest to in: of, hippias, few, basaltic, the, qualifications, steric, element,
# Nearest to have: necronomicon, size, impoverished, fertilize, chah, unsatisfied, splendour, little,
# Nearest to five: zero, two, one, eight, six, four, seven, three,
# Nearest to first: substituting, qe, awesome, danville, incorporation, wonderful, calculus, gru,
# Nearest to time: chungcheong, deep, regencies, punter, most, constructor, veishea, victory,
# Nearest to over: both, subdivision, female, definition, enumerated, necessitating, anime, ormond,
# Nearest to not: requires, partitioning, itself, elephants, ambiguities, doesn, multiplications, therefore,
# Nearest to grand: dignified, hindrance, chops, aruch, around, boudica, pedersen, moines,
# Nearest to award: awards, academy, best, received, awarded, won, recipients, prejudicial,
# Nearest to assembly: pluriform, branch, bicameral, transferable, system, electoral, internationally, amended,
# Nearest to cost: price, error, funds, flexible, manages, amounting, telstra, geodesic,
# Nearest to creation: doomsday, pang, ifab, involvements, mill, decaying, socratic, humans,
# Nearest to engineering: getter, connectionless, development, tptp, applications, disciplines, mulliken, industrialization,
# Nearest to test: diminishes, islander, disabled, korzybski, demonstrator, promoted, chs, bohlen,
# Nearest to ice: thickness, vagrant, creams, spray, meats, digging, skier, tecumseh,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0792 0.0724 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0920 0.0719 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0868 0.0768 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0425 0.0811 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0744 0.0732 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0590 0.0775 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0630 0.0740 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0174 0.0782 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0755 0.0793 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0657 0.0789 sec/batch
# Nearest to three: two, six, eight, nine, four, zero, five, one,
# Nearest to in: of, hippias, few, the, basaltic, qualifications, one, after,
# Nearest to have: necronomicon, impoverished, splendour, chah, unsatisfied, little, size, schengen,
# Nearest to five: zero, two, one, six, eight, four, seven, three,
# Nearest to first: substituting, incorporation, gru, qe, calculus, unconvincing, circumcising, jaina,
# Nearest to time: chungcheong, deep, regencies, anachronistic, victory, punter, constructor, augmented,
# Nearest to over: both, subdivision, definition, enumerated, two, anime, female, ormond,
# Nearest to not: ambiguities, partitioning, elephants, requires, itself, doesn, multiplications, that,
# Nearest to grand: dignified, hindrance, chops, aruch, boudica, moines, around, pedersen,
# Nearest to award: academy, awards, best, awarded, received, won, recipients, actresses,
# Nearest to assembly: pluriform, bicameral, branch, system, transferable, amended, internationally, serve,
# Nearest to cost: price, funds, error, amounting, flexible, manages, telstra, purchases,
# Nearest to creation: doomsday, pang, ifab, involvements, jens, mill, decaying, kosovo,
# Nearest to engineering: getter, connectionless, tptp, applications, development, mulliken, diez, industrialization,
# Nearest to test: diminishes, islander, korzybski, demonstrator, disabled, bohlen, endangered, chs,
# Nearest to ice: thickness, vagrant, creams, spray, meats, tecumseh, tinctures, digging,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0559 0.0806 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0277 0.0752 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0323 0.0739 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0706 0.0722 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0645 0.0714 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1407 0.0731 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1410 0.0731 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0489 0.0746 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0364 0.0761 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0546 0.0727 sec/batch
# Nearest to three: two, six, nine, eight, zero, four, five, one,
# Nearest to in: of, few, the, cappella, hippias, qualifications, basaltic, steric,
# Nearest to have: necronomicon, impoverished, schengen, them, size, chah, fertilize, brisance,
# Nearest to five: zero, two, six, one, eight, four, seven, three,
# Nearest to first: incorporation, substituting, gru, danville, second, unconvincing, the, calculus,
# Nearest to time: chungcheong, deep, regencies, punter, victory, most, augmented, veishea,
# Nearest to over: subdivision, both, definition, female, anime, two, enumerated, live,
# Nearest to not: ambiguities, partitioning, requires, elephants, itself, doesn, imposed, suppose,
# Nearest to grand: dignified, chops, hindrance, pedersen, moines, around, aruch, boudica,
# Nearest to award: academy, awards, best, awarded, won, received, recipients, grammy,
# Nearest to assembly: pluriform, bicameral, branch, amended, transferable, system, elects, internationally,
# Nearest to cost: price, amounting, funds, flexible, manages, error, telstra, money,
# Nearest to creation: pang, doomsday, ifab, involvements, decaying, efik, gantry, mill,
# Nearest to engineering: getter, connectionless, applications, tptp, diez, industrialization, development, mulliken,
# Nearest to test: diminishes, islander, endangered, korzybski, wind, chs, demonstrator, disabled,
# Nearest to ice: vagrant, thickness, creams, spray, tecumseh, digging, summer, coppersmith,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9498 0.0830 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0183 0.0779 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0013 0.0860 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0301 0.0833 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1154 0.0785 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0660 0.0745 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9885 0.0776 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9800 0.0773 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0139 0.0769 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0014 0.0777 sec/batch
# Nearest to three: two, six, nine, zero, eight, four, one, five,
# Nearest to in: of, hippias, the, few, after, qualifications, cappella, only,
# Nearest to have: necronomicon, them, fertilize, size, impoverished, schengen, chah, unsatisfied,
# Nearest to five: zero, two, one, six, eight, four, seven, three,
# Nearest to first: substituting, incorporation, gru, the, second, epping, danville, unconvincing,
# Nearest to time: chungcheong, regencies, most, deep, punter, victory, veishea, anachronistic,
# Nearest to over: subdivision, both, female, definition, anime, live, enumerated, two,
# Nearest to not: requires, ambiguities, multiplications, that, partitioning, itself, doesn, elephants,
# Nearest to grand: dignified, pedersen, chops, hindrance, moines, around, chanel, aruch,
# Nearest to award: academy, awards, best, awarded, won, received, recipients, prejudicial,
# Nearest to assembly: pluriform, bicameral, system, branch, transferable, amended, serve, elects,
# Nearest to cost: price, funds, amounting, manages, flexible, money, error, telstra,
# Nearest to creation: pang, doomsday, ifab, decaying, involvements, gantry, efik, mill,
# Nearest to engineering: getter, connectionless, industrialization, diez, development, tptp, applications, mulliken,
# Nearest to test: diminishes, wind, islander, endangered, demonstrator, disabled, chs, bohlen,
# Nearest to ice: vagrant, thickness, creams, tecumseh, skier, summer, spray, coppersmith,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9850 0.0780 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9144 0.0769 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0307 0.0809 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0184 0.0778 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0077 0.0789 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0017 0.0814 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9172 0.0764 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9417 0.0732 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9271 0.0734 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9890 0.0722 sec/batch
# Nearest to three: two, six, zero, eight, nine, four, five, one,
# Nearest to in: of, the, hippias, one, steric, few, only, is,
# Nearest to have: size, fertilize, them, necronomicon, city, unsatisfied, impoverished, little,
# Nearest to five: zero, two, six, one, four, eight, seven, three,
# Nearest to first: substituting, the, second, fourth, incorporation, gru, until, th,
# Nearest to time: chungcheong, regencies, punter, most, scanner, equals, veishea, anachronistic,
# Nearest to over: both, two, female, subdivision, at, population, vaporizes, live,
# Nearest to not: requires, ambiguities, that, itself, elephants, multiplications, partitioning, doesn,
# Nearest to grand: dignified, hindrance, chops, moines, pedersen, around, aruch, chanel,
# Nearest to award: academy, awards, awarded, won, best, received, recipients, prejudicial,
# Nearest to assembly: pluriform, bicameral, branch, transferable, system, serve, amended, elects,
# Nearest to cost: price, manages, funds, amounting, flexible, error, money, telstra,
# Nearest to creation: doomsday, pang, ifab, decaying, efik, gantry, involvements, banal,
# Nearest to engineering: getter, diez, industrialization, connectionless, disciplines, tptp, mulliken, formative,
# Nearest to test: diminishes, endangered, islander, wind, chs, disabled, korzybski, bohlen,
# Nearest to ice: vagrant, thickness, creams, spray, layer, skier, tinctures, summer,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9984 0.0731 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0024 0.0717 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9650 0.0718 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9958 0.0724 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0512 0.0768 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9732 0.0732 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9785 0.0714 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0013 0.0721 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9918 0.0722 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0011 0.0723 sec/batch
# Nearest to three: two, six, eight, nine, zero, four, five, one,
# Nearest to in: of, the, only, hippias, qualifications, a, is, with,
# Nearest to have: size, necronomicon, them, fertilize, unsatisfied, little, city, chah,
# Nearest to five: zero, two, six, one, eight, four, seven, three,
# Nearest to first: the, unconvincing, gru, fourth, incorporation, substituting, second, th,
# Nearest to time: chungcheong, punter, scanner, deep, equals, veishea, victory, most,
# Nearest to over: both, definition, female, subdivision, necessitating, anime, vaporizes, live,
# Nearest to not: requires, that, itself, ambiguities, partitioning, imposed, multiplications, elephants,
# Nearest to grand: dignified, hindrance, moines, chops, pedersen, aruch, chanel, banner,
# Nearest to award: academy, awards, awarded, best, won, received, recipients, prejudicial,
# Nearest to assembly: pluriform, bicameral, transferable, system, elects, branch, amended, serve,
# Nearest to cost: price, funds, amounting, manages, error, flexible, freddie, money,
# Nearest to creation: doomsday, pang, ifab, decaying, socratic, gantry, humans, virility,
# Nearest to engineering: getter, connectionless, disciplines, applications, tptp, industrialization, mulliken, formative,
# Nearest to test: diminishes, korzybski, islander, endangered, wind, disabled, chs, originally,
# Nearest to ice: vagrant, thickness, creams, spray, skier, coppersmith, tinctures, layer,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0016 0.0771 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9842 0.0824 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9676 0.0820 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9857 0.0782 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0391 0.0834 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9931 0.0717 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9797 0.0719 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9772 0.0716 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9482 0.0717 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0517 0.0812 sec/batch
# Nearest to three: two, six, eight, nine, four, zero, one, five,
# Nearest to in: of, the, after, only, for, hippias, few, qualifications,
# Nearest to have: size, necronomicon, little, them, city, chah, fertilize, swiss,
# Nearest to five: zero, two, six, four, one, eight, seven, three,
# Nearest to first: the, substituting, incorporation, fourth, second, unconvincing, were, th,
# Nearest to time: chungcheong, regencies, deep, equals, augmented, punter, difference, scanner,
# Nearest to over: both, subdivision, two, female, definition, necessitating, live, at,
# Nearest to not: requires, itself, ambiguities, partitioning, that, imposed, this, elephants,
# Nearest to grand: dignified, moines, hindrance, aruch, chanel, bonding, chops, pedersen,
# Nearest to award: academy, awards, awarded, best, won, received, grammy, recipients,
# Nearest to assembly: bicameral, pluriform, amended, elects, transferable, serve, system, branch,
# Nearest to cost: price, funds, amounting, manages, error, freddie, flexible, telstra,
# Nearest to creation: pang, doomsday, ifab, decaying, gantry, jens, cold, involvements,
# Nearest to engineering: getter, connectionless, development, applications, tptp, industrialization, disciplines, diez,
# Nearest to test: diminishes, endangered, wind, islander, korzybski, chs, chances, bohlen,
# Nearest to ice: vagrant, thickness, creams, spray, layer, tinctures, summer, coppersmith,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9999 0.0891 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0797 0.0715 sec/batch
# ...
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8276 0.0754 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8650 0.0753 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8510 0.0765 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7961 0.0752 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8706 0.0751 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9165 0.0752 sec/batch
# Nearest to three: two, six, eight, one, four, nine, five, zero,
# Nearest to in: of, the, a, only, for, is, which, as,
# Nearest to have: that, them, many, are, size, since, unsatisfied, but,
# Nearest to five: zero, two, eight, four, six, one, three, seven,
# Nearest to first: the, second, as, in, by, were, gru, th,
# Nearest to time: chungcheong, punter, difference, talents, alameda, over, most, finalized,
# Nearest to over: years, both, at, live, definition, two, female, become,
# Nearest to not: that, this, to, it, but, itself, in, all,
# Nearest to grand: dignified, moines, chops, limburgish, prix, demarcating, aruch, dealing,
# Nearest to award: awards, awarded, academy, won, best, received, recipients, grammy,
# Nearest to assembly: behaves, amended, congreso, pluriform, transferable, assembl, assemblies, boziz,
# Nearest to cost: amounting, price, freddie, reproductive, error, signetics, probabilities, warriors,
# Nearest to creation: cold, cooler, created, humans, gantry, doomsday, pang, decaying,
# Nearest to engineering: academia, getter, insidious, creativity, mulliken, tptp, disciplines, feasibility,
# Nearest to test: endangered, tested, diminishes, originally, tests, ban, apply, hazardous,
# Nearest to ice: vagrant, thickness, creams, skier, tinctures, froze, spray, hockey,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8197 0.0780 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8661 0.0772 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8271 0.0767 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8551 0.0754 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8460 0.0783 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8948 0.0771 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8585 0.0759 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8543 0.0774 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8721 0.0775 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8717 0.0765 sec/batch
# Nearest to three: two, six, one, eight, four, nine, five, zero,
# Nearest to in: of, the, a, for, as, which, and, with,
# Nearest to have: them, that, many, since, unsatisfied, are, been, not,
# Nearest to five: zero, two, eight, four, six, one, three, seven,
# Nearest to first: the, second, by, in, were, as, to, though,
# Nearest to time: chungcheong, talents, difference, formal, punter, scanner, impulse, dava,
# Nearest to over: years, both, definition, two, live, zero, six, become,
# Nearest to not: that, this, it, itself, to, in, but, only,
# Nearest to grand: dignified, chops, prix, moines, limburgish, dealing, centralization, aruch,
# Nearest to award: awards, awarded, academy, best, won, recipients, grammy, received,
# Nearest to assembly: amended, behaves, congreso, transferable, boziz, pluriform, saucer, junior,
# Nearest to cost: amounting, price, freddie, reproductive, funds, error, probabilities, purchases,
# Nearest to creation: cold, created, cooler, gantry, pang, decaying, doomsday, lx,
# Nearest to engineering: getter, connectionless, mulliken, creativity, academia, applications, insidious, tptp,
# Nearest to test: endangered, tested, diminishes, tests, apply, originally, ban, wind,
# Nearest to ice: thickness, vagrant, creams, skier, froze, tinctures, freezing, hockey,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8723 0.0767 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8421 0.0753 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8433 0.0760 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8295 0.0762 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9174 0.0771 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8388 0.0863 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9691 0.0815 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9003 0.0752 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9230 0.0757 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8134 0.0748 sec/batch
# Nearest to three: two, six, four, one, eight, nine, zero, five,
# Nearest to in: of, the, for, a, with, after, at, and,
# Nearest to have: that, them, many, unsatisfied, since, but, are, not,
# Nearest to five: zero, two, four, eight, one, six, three, seven,
# Nearest to first: the, second, by, were, th, in, eliminated, after,
# Nearest to time: chungcheong, talents, formal, coincide, dava, difference, plague, punter,
# Nearest to over: years, both, become, live, two, definition, zero, at,
# Nearest to not: that, this, it, itself, but, however, have, to,
# Nearest to grand: dignified, prix, chops, moines, limburgish, dealing, centralization, demarcating,
# Nearest to award: awards, awarded, academy, won, grammy, best, recipients, hugo,
# Nearest to assembly: amended, behaves, congreso, pluriform, boziz, assembl, transferable, saucer,
# Nearest to cost: amounting, price, freddie, reproductive, funds, signetics, probabilities, flexible,
# Nearest to creation: cold, created, gantry, cooler, pang, decaying, spring, lx,
# Nearest to engineering: getter, connectionless, mulliken, insidious, academia, creativity, feasibility, diez,
# Nearest to test: endangered, tested, tests, diminishes, apply, originally, chances, ebonics,
# Nearest to ice: vagrant, thickness, skier, creams, hockey, tinctures, froze, freezing,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7866 0.0804 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8557 0.0910 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7925 0.0796 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8650 0.0802 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8344 0.0765 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8731 0.0767 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8537 0.0537 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8191 0.0764 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8261 0.0753 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8665 0.0744 sec/batch
# Nearest to three: two, six, one, eight, four, nine, zero, five,
# Nearest to in: of, the, a, for, after, which, with, an,
# Nearest to have: them, that, unsatisfied, many, since, are, not, but,
# Nearest to five: zero, two, four, eight, one, six, three, seven,
# Nearest to first: the, second, in, by, were, after, eliminated, th,
# Nearest to time: chungcheong, formal, talents, most, finalized, ashram, plague, coincide,
# Nearest to over: years, both, at, live, definition, female, become, zero,
# Nearest to not: that, this, it, to, however, but, itself, be,
# Nearest to grand: dignified, prix, chops, moines, limburgish, dealing, demarcating, abundantly,
# Nearest to award: awards, awarded, academy, won, best, grammy, globe, recipients,
# Nearest to assembly: amended, behaves, congreso, saucer, transferable, pluriform, nextstep, assembl,
# Nearest to cost: amounting, price, freddie, reproductive, need, funds, probabilities, flexible,
# Nearest to creation: created, gantry, cold, cooler, pang, decaying, lx, doomsday,
# Nearest to engineering: creativity, getter, connectionless, mulliken, academia, insidious, feasibility, diez,
# Nearest to test: tested, endangered, tests, diminishes, spaceshipone, chances, sopron, apply,
# Nearest to ice: vagrant, thickness, creams, skier, hockey, tinctures, freezing, froze,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8147 0.0749 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8334 0.0737 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7908 0.0737 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8129 0.0733 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8120 0.0749 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8287 0.0739 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8963 0.0763 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7261 0.0784 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8410 0.0777 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7848 0.0763 sec/batch
# Nearest to three: two, four, six, one, eight, zero, five, nine,
# Nearest to in: of, the, a, is, for, and, which, an,
# Nearest to have: that, them, since, many, are, not, been, but,
# Nearest to five: zero, four, two, eight, six, one, three, seven,
# Nearest to first: the, second, by, were, in, after, th, as,
# Nearest to time: chungcheong, difference, formal, talents, compared, finalized, most, alameda,
# Nearest to over: years, both, at, zero, two, six, live, one,
# Nearest to not: that, this, it, be, all, to, but, itself,
# Nearest to grand: dignified, prix, moines, limburgish, chops, demarcating, centralization, abundantly,
# Nearest to award: awards, awarded, academy, won, best, grammy, recipients, globe,
# Nearest to assembly: amended, behaves, congreso, assemblies, assembl, pluriform, transferable, psoe,
# Nearest to cost: amounting, freddie, price, reproductive, probabilities, pala, reciprocals, signetics,
# Nearest to creation: created, cold, gantry, cooler, decaying, pang, lx, spring,
# Nearest to engineering: creativity, insidious, connectionless, getter, biostatistics, academia, mulliken, disciplines,
# Nearest to test: endangered, tested, tests, diminishes, apply, thc, wind, chances,
# Nearest to ice: vagrant, creams, thickness, skier, hockey, tinctures, freezing, spray,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7744 0.0777 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8208 0.0761 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8599 0.0759 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7954 0.0761 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8334 0.0765 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8918 0.0767 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8116 0.0762 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8288 0.0776 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8401 0.0778 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8490 0.0784 sec/batch
# Nearest to three: two, four, six, one, eight, nine, five, zero,
# Nearest to in: of, the, a, for, is, which, as, an,
# Nearest to have: that, many, them, since, are, unsatisfied, not, been,
# Nearest to five: zero, four, two, eight, six, one, three, seven,
# Nearest to first: the, second, in, by, as, were, a, to,
# Nearest to time: chungcheong, talents, punter, alameda, difference, recover, over, a,
# Nearest to over: years, both, at, become, zero, live, one, eventually,
# Nearest to not: that, this, but, it, itself, to, only, have,
# Nearest to grand: dignified, prix, moines, limburgish, chops, dealing, demarcating, centralization,
# Nearest to award: awards, awarded, academy, won, best, grammy, recipients, received,
# Nearest to assembly: amended, congreso, behaves, assemblies, assembl, pluriform, transferable, boziz,
# Nearest to cost: amounting, price, freddie, reproductive, probabilities, signetics, need, pala,
# Nearest to creation: created, cold, gantry, cooler, pang, decaying, doomsday, humans,
# Nearest to engineering: creativity, insidious, academia, getter, biostatistics, connectionless, feasibility, tptp,
# Nearest to test: tested, tests, endangered, diminishes, assessing, apply, thc, chances,
# Nearest to ice: vagrant, creams, thickness, skier, hockey, tinctures, froze, spray,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8659 0.0769 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8651 0.0753 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8385 0.0773 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8193 0.0765 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8804 0.0763 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8508 0.0777 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8424 0.0751 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8271 0.0767 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8155 0.0757 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8427 0.0768 sec/batch
# Nearest to three: two, four, six, one, eight, nine, five, zero,
# Nearest to in: of, the, a, for, which, as, is, with,
# Nearest to have: that, many, them, been, but, since, are, not,
# Nearest to five: zero, four, two, eight, six, one, three, seven,
# Nearest to first: the, second, in, by, were, as, th, eliminated,
# Nearest to time: chungcheong, most, formal, talents, alameda, coincide, finalized, once,
# Nearest to over: years, one, both, six, zero, two, at, definition,
# Nearest to not: that, it, in, this, but, to, itself, have,
# Nearest to grand: dignified, prix, moines, dealing, chops, limburgish, demarcating, centralization,
# Nearest to award: awards, awarded, academy, best, won, recipients, grammy, hugo,
# Nearest to assembly: amended, behaves, congreso, assembl, boziz, pluriform, assemblies, psoe,
# Nearest to cost: amounting, freddie, price, reproductive, need, probabilities, submarines, purchases,
# Nearest to creation: created, cold, gantry, cooler, decaying, pang, doomsday, see,
# Nearest to engineering: creativity, insidious, academia, getter, connectionless, biostatistics, feasibility, tptp,
# Nearest to test: endangered, tested, tests, assessing, apply, diminishes, hazardous, thc,
# Nearest to ice: vagrant, creams, thickness, hockey, skier, tinctures, froze, freezing,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8650 0.0807 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8275 0.0781 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9282 0.0759 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9064 0.0755 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8938 0.0754 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8285 0.0751 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7676 0.0763 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8194 0.0768 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7536 0.0770 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8396 0.0804 sec/batch
# Nearest to three: two, six, one, four, nine, eight, zero, five,
# Nearest to in: the, of, a, for, which, as, is, an,
# Nearest to have: that, many, since, but, not, been, them, some,
# Nearest to five: zero, two, four, eight, six, one, three, seven,
# Nearest to first: the, second, in, by, th, were, after, eliminated,
# Nearest to time: a, chungcheong, formal, most, coincide, dava, difference, talents,
# Nearest to over: years, live, zero, continued, at, both, definition, six,
# Nearest to not: that, it, have, but, this, some, itself, however,
# Nearest to grand: dignified, prix, moines, dealing, chops, limburgish, xxxi, demarcating,
# Nearest to award: awards, awarded, academy, best, recipients, won, grammy, received,
# Nearest to assembly: amended, assembl, congreso, behaves, pluriform, psoe, assemblies, transferable,
# Nearest to cost: amounting, price, freddie, probabilities, reproductive, need, purchases, honest,
# Nearest to creation: created, cold, gantry, decaying, cooler, pang, lx, doomsday,
# Nearest to engineering: creativity, insidious, getter, feasibility, academia, connectionless, mulliken, biostatistics,
# Nearest to test: endangered, tests, tested, assessing, diminishes, hazardous, sopron, apply,
# Nearest to ice: vagrant, thickness, hockey, creams, skier, froze, tinctures, freezing,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8413 0.0801 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8441 0.0766 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
